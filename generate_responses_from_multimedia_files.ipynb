# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv(), override=True)
api_key = os.environ.get('GOOGLE_API_KEY')
genai.configure(api_key=api_key)

# %% [markdown]
# # for prompts based on uploaded images

# %%
#to take interactiveness and visuality of jupy-nb to next level
from IPython.display import Image, Markdown

# to display image
Image(filename='greece.jpg')

# %%
# to upload file
img_file = genai.upload_file(path='greece.jpg', display_name="GREECE")
print(f'uploaded file:{img_file.display_name} as {img_file.uri}')

# to retrive the uploaded file
retrieved_img_file = genai.get_file(name=img_file.name)
print(f'uploaded file:{retrieved_img_file.display_name} as {retrieved_img_file.uri}')
# Out:
# uploaded file:GREECE as https://generativelanguage.googleapis.com/v1beta/files/e22p7gi8fz72
# uploaded file:GREECE as https://generativelanguage.googleapis.com/v1beta/files/e22p7gi8fz72

# %%
# to create model 
model = genai.GenerativeModel('gemini-1.5-pro-latest')

# to pass the image file, prompt and to get the response
prompt = 'describe the image considering historical facts'
response = model.generate_content([prompt, img_file])
print(response.text)
# Out:
# This is Navagio Beach (also known as Shipwreck Beach) on the island of Zakynthos, Greece. The cove's defining feature is the wrecked freightliner, the MV Panagiotis, which is often mistakenly thought to be a pirate ship.
#
# The Panagiotis ran aground in 1980 during stormy weather. Some speculate the ship was smuggling cigarettes, though the true nature of its cargo is debated. The event, regardless of the cargo, cemented the beach's place in popular culture and led to its nickname.
#
# The image showcases the dramatic landscape of the Ionian islands: sheer limestone cliffs, vibrant turquoise waters, and lush vegetation typical of the Mediterranean region. The presence of tourist boats speaks to the area's popularity as a destination, drawing visitors to its natural beauty and intriguing history.

# %% [markdown]
# # for prompts based on uploaded audio files

# %%
# to upload file
audio_file = genai.upload_file(path='sundarakanda.mp3', display_name="SUNDARAKANDA")
print(f'uploaded file:{audio_file.display_name} as {audio_file.uri}')

# to retrive the uploaded file
retrieved_audio_file = genai.get_file(name=audio_file.name)
print(f'retrieved file:{retrieved_audio_file.display_name} as {retrieved_audio_file.uri}')
# Out:
# uploaded file:SUNDARAKANDA as https://generativelanguage.googleapis.com/v1beta/files/45f8wlt9c9nj
# retrieved file:SUNDARAKANDA as https://generativelanguage.googleapis.com/v1beta/files/45f8wlt9c9nj

# %%
# to create model 
model = genai.GenerativeModel('gemini-1.5-pro-latest')

# to pass the audio file, prompt and to get the response
prompt = 'the audio is in sanskrit, can u concise it in english please.'
response = model.generate_content([prompt, audio_file])
print(response.text)
# Out:
# The audio describes a scene from the Ramayana. It details Sita's distress after being abducted by Ravana.
#
# Sita, adorned with jewels and flowers, is seen in the Ashoka Vatika, surrounded by fearsome Rakshasis. She is grieving, her face stained with tears, longing for Rama. The beauty of the Vatika, filled with fragrant flowers and trees, fails to console her. The scene emphasizes her sorrow and helplessness as she yearns for Rama's return.
#
# Hanuman, searching for Sita, observes her despair. He notices her tattered clothes and the remnants of her luxurious possessions scattered on the ground. Her sorrow is compared to the smoke from a fire, spreading everywhere.
#
# The narration evokes empathy for Sita's plight and highlights the depth of her love for Rama. The imagery of nature's beauty juxtaposed with Sita's sorrow amplifies the tragedy of her situation.

# %% [markdown]
# # for prompts based on uploaded video files

# %%
# to upload file
video_file = genai.upload_file(path='zajendra_moksham.mp4', display_name="Gajendra Moksham")
print(f'uploaded file:{video_file.display_name} as {video_file.uri}')

# to retrive the uploaded file
retrieved_video_file = genai.get_file(name=video_file.name)
print(f'retrieved file:{retrieved_video_file.display_name} as {retrieved_video_file.uri}')
# Out:
# uploaded file:Gajendra Moksham as https://generativelanguage.googleapis.com/v1beta/files/qnybe8ne7ju3
# retrieved file:Gajendra Moksham as https://generativelanguage.googleapis.com/v1beta/files/qnybe8ne7ju3

# %%
# to create model 
model = genai.GenerativeModel('gemini-1.5-pro-latest')

# to pass the video file, prompt and to get the response
prompt = 'Please summarize the key points of the video, which contains English-based Sanskrit transliteration.'
response = model.generate_content([prompt, video_file])
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[48], line 6
#       4 # to pass the video file, prompt and to get the response
#       5 prompt = 'Please summarize the key points of the video, which contains English-based Sanskrit transliteration.'
# ----> 6 response = model.generate_content([prompt, video_file])
#       7 print(response.text)
#
# File ~\OneDrive\Desktop\New folder\my-env\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
# ...
